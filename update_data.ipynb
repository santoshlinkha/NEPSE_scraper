# %%
import pandas as pd


# import datetime

# x = datetime.datetime.now()
# today_date = x.strftime("%m/%d/%Y")

# pages = 12
# df = []

# columns = ["Symbol","Date","Open","High","Low","Close","Percent Change","Volume"]

# for page in range(pages):
#     url = "http://www.nepalstock.com/main/todays_price/" + str(page+1)    
#     data = pd.read_html(url)[0]
#     data = data.iloc[2:-4]
# data

# %%
data = pd.read_csv("database.csv")
data
# Out:
#         Unnamed: 0 Symbol        Date    Open    High     Low   Close  \
# 0                0  SRD80  2020-12-29  1000.0  1000.0  1000.0  1000.0
# 1                1  SRD80  2020-12-30  1020.0  1060.0  1020.0  1060.0
# 2                2  SRD80  2020-12-31  1080.0  1080.0  1059.0  1059.0
# 3                3  SRD80  2021-01-03  1050.0  1050.0  1050.0  1050.0
# 4                4  SRD80  2021-01-04  1050.0  1050.0  1050.0  1050.0
# ...            ...    ...         ...     ...     ...     ...     ...
# 296407      296407  AKBSL  2019-12-15   466.0   466.0   451.0   457.0
# 296408      296408  AKBSL  2019-12-16   465.0   465.0   440.0   448.0
# 296409      296409  AKBSL  2019-12-17   440.0   480.0   440.0   479.0
# 296410      296410  AKBSL  2019-12-18   486.0   486.0   467.0   474.0
# 296411      296411  AKBSL  2019-12-19   465.0   465.0   465.0   465.0
#
#        Percent Change  Volume
# 0                 0.0    10.0
# 1                0.06   300.0
# 2                -0.0    68.0
# 3               -0.01   200.0
# 4                 0.0    50.0
# ...               ...     ...
# 296407          -3.38   770.0
# 296408          -4.07  3850.0
# 296409           6.92  4071.0
# 296410          -1.04  1610.0
# 296411           -1.9    30.0
#
# [296412 rows x 9 columns]

# %%
data.iloc[:,1:].to_csv("database.csv")
